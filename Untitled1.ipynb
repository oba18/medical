# %%
import matplotlib.pyplot as plt
import pydicom
import glob

# %%
# files = glob.glob(
#     '/Volumes/masashi/workspace/0_KML/0_medical/0_data/LIDC-IDRI/LIDC-IDRI-0078/01-01-2000-68432/3165.000000-53824/1-3'
# )

path = '/Volumes/masashi/workspace/0_KML/0_medical/0_data/LIDC-IDRI/LIDC-IDRI-0078/01-01-2000-68432/3165.000000-53824/1-87.dcm'

ds = pydicom.dcmread(path)
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
